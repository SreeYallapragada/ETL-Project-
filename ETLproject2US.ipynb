# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from sqlalchemy import create_engine
import psycopg2

#Store Part I results into DataFrame
#Load the data to a DataFrame
accident_data = pd.read_csv("/Users/erikaberry/Desktop/Traffic_Accidents/data/USTrafficAccidents.csv", encoding="utf-8")
accident_data.head()
# Out:
#     ID    Source  TMC  Severity   Start_Time      End_Time  Start_Lat  \
# 0  A-1  MapQuest  201         3  2/8/16 5:46  2/8/16 11:00  39.865147
# 1  A-2  MapQuest  201         2  2/8/16 6:07   2/8/16 6:37  39.928059
# 2  A-3  MapQuest  201         2  2/8/16 6:49   2/8/16 7:19  39.063148
# 3  A-4  MapQuest  201         3  2/8/16 7:23   2/8/16 7:53  39.747753
# 4  A-5  MapQuest  201         2  2/8/16 7:39   2/8/16 8:09  39.627781
#
#    Start_Lng  End_Lat  End_Lng  ...  Roundabout Station   Stop  \
# 0 -84.058723      NaN      NaN  ...       False   False  False
# 1 -82.831184      NaN      NaN  ...       False   False  False
# 2 -84.032608      NaN      NaN  ...       False   False  False
# 3 -84.205582      NaN      NaN  ...       False   False  False
# 4 -84.188354      NaN      NaN  ...       False   False  False
#
#   Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset Civil_Twilight  \
# 0           False          False        False          Night          Night
# 1           False          False        False          Night          Night
# 2           False           True        False          Night          Night
# 3           False          False        False          Night            Day
# 4           False           True        False            Day            Day
#
#   Nautical_Twilight Astronomical_Twilight
# 0             Night                 Night
# 1             Night                   Day
# 2               Day                   Day
# 3               Day                   Day
# 4               Day                   Day
#
# [5 rows x 49 columns]

# %%
# Data cleanup

# Filters out dates containing 2016, 2017, & 2019 -- too much data in dataset to handle with laptops
accident_data_revised = accident_data[~accident_data["Start_Time"].str.contains("2016")]
accident_data_revised = accident_data_revised[~accident_data_revised["Start_Time"].str.contains("2017")]
accident_data_revised = accident_data_revised[~accident_data_revised["Start_Time"].str.contains("2018")]

# Splits the Start_Time column into individual columns
accident_data_revised[["Date", "Time"]] = accident_data_revised["Start_Time"].str.split(expand=True)

# Renames columns to be more readable
accident_data_revised = accident_data_revised.rename(columns={"Start_Lat":"Lat", "Start_Lng":"Lng", "Weather_Condition":"Weather"})

# Filters and rearranges dataset to display most useful columns
accident_data_revised = accident_data_revised[["Date", "Time", "Lat", "Lng", "City", "State",
         "County", "Weather", "Nautical_Twilight"]]

# Iterates through all column data to find NaN values and adds them to a list
accident_data_revised.columns[accident_data_revised.isna().any()].tolist()

accident_data_revised = accident_data_revised.reset_index()

accident_data_revised.head(20)
# Out:
#     index    Date  Time        Lat        Lng          City State      County  \
# 0       0  2/8/16  5:46  39.865147 -84.058723        Dayton    OH  Montgomery
# 1       1  2/8/16  6:07  39.928059 -82.831184  Reynoldsburg    OH    Franklin
# 2       2  2/8/16  6:49  39.063148 -84.032608  Williamsburg    OH    Clermont
# 3       3  2/8/16  7:23  39.747753 -84.205582        Dayton    OH  Montgomery
# 4       4  2/8/16  7:39  39.627781 -84.188354        Dayton    OH  Montgomery
# 5       5  2/8/16  7:44  40.100590 -82.925194   Westerville    OH    Franklin
# 6       6  2/8/16  7:59  39.758274 -84.230507        Dayton    OH  Montgomery
# 7       7  2/8/16  7:59  39.770382 -84.194901        Dayton    OH  Montgomery
# 8       8  2/8/16  8:00  39.778061 -84.172005        Dayton    OH  Montgomery
# 9       9  2/8/16  8:10  40.100590 -82.925194   Westerville    OH    Franklin
# 10     10  2/8/16  8:14  39.952812 -83.119293      Columbus    OH    Franklin
# 11     11  2/8/16  8:21  39.932709 -82.830910  Reynoldsburg    OH    Franklin
# 12     12  2/8/16  8:36  39.737633 -84.149933        Dayton    OH  Montgomery
# 13     13  2/8/16  8:37  39.790760 -84.241547        Dayton    OH  Montgomery
# 14     14  2/8/16  8:39  39.972038 -82.913521      Columbus    OH    Franklin
# 15     15  2/8/16  8:43  39.745888 -84.170410        Dayton    OH  Montgomery
# 16     16  2/8/16  8:53  39.748329 -84.224007        Dayton    OH  Montgomery
# 17     17  2/8/16  9:24  39.752174 -84.239952        Dayton    OH  Montgomery
# 18     18  2/8/16  9:25  39.740669 -84.184135        Dayton    OH  Montgomery
# 19     19  2/8/16  9:35  39.790703 -84.244461        Dayton    OH  Montgomery
#
#           Weather Nautical_Twilight
# 0      Light Rain             Night
# 1      Light Rain             Night
# 2        Overcast               Day
# 3   Mostly Cloudy               Day
# 4   Mostly Cloudy               Day
# 5      Light Rain               Day
# 6        Overcast               Day
# 7        Overcast               Day
# 8   Mostly Cloudy               Day
# 9      Light Rain               Day
# 10           Rain               Day
# 11     Light Rain               Day
# 12       Overcast               Day
# 13  Mostly Cloudy               Day
# 14     Light Rain               Day
# 15       Overcast               Day
# 16  Mostly Cloudy               Day
# 17  Mostly Cloudy               Day
# 18       Overcast               Day
# 19  Mostly Cloudy               Day

# %%
# filter accident_data_sorted to include only NC data

NC_accident_data = accident_data_revised.query('State=="NC"')
NC_accident_data.head()
# Out:
#          index      Date   Time        Lat        Lng       City State  \
# 512339  512339  12/25/19   4:55  35.599384 -80.531868  Salisbury    NC
# 512340  512340  12/25/19   6:40  35.771000 -81.329910    Hickory    NC
# 512341  512341  12/25/19   8:36  35.706032 -81.424911  Hildebran    NC
# 512342  512342  12/25/19   9:49  35.065140 -80.845810  Charlotte    NC
# 512343  512343  12/25/19  12:10  35.223850 -80.745033  Charlotte    NC
#
#              County Weather Nautical_Twilight
# 512339        Rowan    Fair             Night
# 512340      Catawba    Fair               Day
# 512341        Burke    Fair               Day
# 512342  Mecklenburg    Fair               Day
# 512343  Mecklenburg    Fair               Day

# %%
# filter accident_data_sorted to include only Wake County data

Wake_accident_data = NC_accident_data.query('County=="Wake"') 
Wake_accident_data.head()
# Out:
#          index      Date   Time        Lat        Lng     City State County  \
# 512361  512361  12/25/19  12:49  35.799881 -78.727257  Raleigh    NC   Wake
# 512363  512363  12/25/19  13:22  35.753876 -78.635849  Raleigh    NC   Wake
# 512364  512364  12/25/19  14:16  35.800491 -78.666481  Raleigh    NC   Wake
# 512365  512365  12/25/19  15:06  35.838581 -78.324638  Zebulon    NC   Wake
# 512367  512367  12/25/19  16:11  35.756947 -78.700005  Raleigh    NC   Wake
#
#               Weather Nautical_Twilight
# 512361  Mostly Cloudy               Day
# 512363  Mostly Cloudy               Day
# 512364  Mostly Cloudy               Day
# 512365           Fair               Day
# 512367  Mostly Cloudy               Day

# %%
# round off the columns in this manner 
Wake_accidents = Wake_accident_data.round({"Lat":6, "Lng":6})
Wake_accidents.head()
# Out:
#          index      Date   Time        Lat        Lng     City State County  \
# 512361  512361  12/25/19  12:49  35.799881 -78.727257  Raleigh    NC   Wake
# 512363  512363  12/25/19  13:22  35.753876 -78.635849  Raleigh    NC   Wake
# 512364  512364  12/25/19  14:16  35.800491 -78.666481  Raleigh    NC   Wake
# 512365  512365  12/25/19  15:06  35.838581 -78.324638  Zebulon    NC   Wake
# 512367  512367  12/25/19  16:11  35.756947 -78.700005  Raleigh    NC   Wake
#
#               Weather Nautical_Twilight
# 512361  Mostly Cloudy               Day
# 512363  Mostly Cloudy               Day
# 512364  Mostly Cloudy               Day
# 512365           Fair               Day
# 512367  Mostly Cloudy               Day

# %%
Wake_accidents.drop(['index'], axis=1)
# Out:
#              Date   Time        Lat        Lng     City State County  \
# 512361   12/25/19  12:49  35.799881 -78.727257  Raleigh    NC   Wake
# 512363   12/25/19  13:22  35.753876 -78.635849  Raleigh    NC   Wake
# 512364   12/25/19  14:16  35.800491 -78.666481  Raleigh    NC   Wake
# 512365   12/25/19  15:06  35.838581 -78.324638  Zebulon    NC   Wake
# 512367   12/25/19  16:11  35.756947 -78.700005  Raleigh    NC   Wake
# ...           ...    ...        ...        ...      ...   ...    ...
# 1047978   3/12/19  19:14  35.838970 -78.673721  Raleigh    NC   Wake
# 1047979   3/12/19  19:18  35.677074 -78.624901   Garner    NC   Wake
# 1047980   3/12/19  19:25  35.861450 -78.638069  Raleigh    NC   Wake
# 1047983   3/12/19  19:53  35.837669 -78.673141  Raleigh    NC   Wake
# 1047990   3/12/19  21:25  35.757050 -78.665688  Raleigh    NC   Wake
#
#                   Weather Nautical_Twilight
# 512361      Mostly Cloudy               Day
# 512363      Mostly Cloudy               Day
# 512364      Mostly Cloudy               Day
# 512365               Fair               Day
# 512367      Mostly Cloudy               Day
# ...                   ...               ...
# 1047978     Mostly Cloudy               Day
# 1047979     Mostly Cloudy               Day
# 1047980  Scattered Clouds               Day
# 1047983  Scattered Clouds               Day
# 1047990     Partly Cloudy             Night
#
# [12071 rows x 9 columns]

# %%
# Export file as a CSV, without the Pandas index, but with the header
Wake_accident_data.to_csv("Wake_Traffic.csv", sep='|', index=False, header=True)

# %%
connection_string = "postgres:postgres@localhost:5432/TrafficAccidents"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ['cary_accidents', 'wake_accidents', 'premise']

# %%
#pd.read_sql_query('select * from wake_accidents', con=engine).head()
